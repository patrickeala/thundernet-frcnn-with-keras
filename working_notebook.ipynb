# %%
#INITIAL TRAIN RPN FIRST
BACKBONE = "thundernetv1"
DATASET = "/home/henri_tomas/projects/faster-rcnn/frcnn-from-scratch-with-keras/2007_2012_trainval.txt"

# !python train_rpn.py --network $BACKBONE -o simple -p $DATASET -n 4 --num_epochs 50
# Out:
# Using TensorFlow backend.
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-01-09 20:27:51.338835: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-01-09 20:27:53.399735: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-09 20:27:53.400418: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x56351883bb70 executing computations on platform CUDA. Devices:
# 2020-01-09 20:27:53.400461: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-01-09 20:27:53.403879: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2020-01-09 20:27:53.404175: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x5635188a4610 executing computations on platform Host. Devices:
# 2020-01-09 20:27:53.404293: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-01-09 20:27:53.404668: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2020-01-09 20:27:53.404814: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-01-09 20:27:53.406070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-09 20:27:53.406226: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-01-09 20:27:53.406266: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-01-09 20:27:53.406664: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10802 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Parsing annotation files
# {'person': 2358}
# Training images per class:
# {'bg': 0, 'person': 2358}
# Num classes (including bg) = 2
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 854
# Num val samples 171
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# x1: (?, ?, ?, 256)
# x2: (?, 20, 20, 256)
# x3: (?, 20, 20, 256)
# loading weights from ./pretrain/mobilenet_1_0_224_tf.h5
# loaded weights!
# Starting training
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# 1000/1000 [==============================] - 106s 106ms/step - loss: 7.5247 - rpn_out_class_loss: 7.1222 - rpn_out_regress_loss: 0.4026 - val_loss: 6.9763 - val_rpn_out_class_loss: 6.5762 - val_rpn_out_regress_loss: 0.4001
# Epoch 2/50
# 1000/1000 [==============================] - 96s 96ms/step - loss: 5.9731 - rpn_out_class_loss: 5.6094 - rpn_out_regress_loss: 0.3638 - val_loss: 4.9327 - val_rpn_out_class_loss: 4.6310 - val_rpn_out_regress_loss: 0.3016
# Epoch 3/50
# 1000/1000 [==============================] - 95s 95ms/step - loss: 4.9451 - rpn_out_class_loss: 4.6250 - rpn_out_regress_loss: 0.3201 - val_loss: 4.0854 - val_rpn_out_class_loss: 3.8053 - val_rpn_out_regress_loss: 0.2801
# Epoch 4/50
# 1000/1000 [==============================] - 96s 96ms/step - loss: 4.3549 - rpn_out_class_loss: 4.0786 - rpn_out_regress_loss: 0.2763 - val_loss: 3.8167 - val_rpn_out_class_loss: 3.5399 - val_rpn_out_regress_loss: 0.2768
#
# Epoch 00004: loss improved from inf to 4.35489, saving model to ./models/rpn/rpn.thundernetv1.weights.04-4.35.hdf5
# Epoch 5/50
# 1000/1000 [==============================] - 96s 96ms/step - loss: 4.0679 - rpn_out_class_loss: 3.7758 - rpn_out_regress_loss: 0.2921 - val_loss: 2.9632 - val_rpn_out_class_loss: 2.6814 - val_rpn_out_regress_loss: 0.2818
# Epoch 6/50
# 1000/1000 [==============================] - 96s 96ms/step - loss: 3.6354 - rpn_out_class_loss: 3.3529 - rpn_out_regress_loss: 0.2824 - val_loss: 3.4369 - val_rpn_out_class_loss: 3.1621 - val_rpn_out_regress_loss: 0.2748
# Epoch 7/50
# 1000/1000 [==============================] - 97s 97ms/step - loss: 3.3410 - rpn_out_class_loss: 3.0644 - rpn_out_regress_loss: 0.2766 - val_loss: 3.1273 - val_rpn_out_class_loss: 2.8542 - val_rpn_out_regress_loss: 0.2732
# Epoch 8/50
# 1000/1000 [==============================] - 97s 97ms/step - loss: 3.1998 - rpn_out_class_loss: 2.9349 - rpn_out_regress_loss: 0.2649 - val_loss: 2.9045 - val_rpn_out_class_loss: 2.6150 - val_rpn_out_regress_loss: 0.2896
#
# Epoch 00008: loss improved from 4.35489 to 3.19977, saving model to ./models/rpn/rpn.thundernetv1.weights.08-3.20.hdf5
# Epoch 9/50
# 1000/1000 [==============================] - 97s 97ms/step - loss: 2.8486 - rpn_out_class_loss: 2.5871 - rpn_out_regress_loss: 0.2615 - val_loss: 2.7943 - val_rpn_out_class_loss: 2.5258 - val_rpn_out_regress_loss: 0.2685
# Epoch 10/50
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.6183 - rpn_out_class_loss: 2.3516 - rpn_out_regress_loss: 0.2668 - val_loss: 1.9901 - val_rpn_out_class_loss: 1.7348 - val_rpn_out_regress_loss: 0.2553
# Epoch 11/50
# 1000/1000 [==============================] - 98s 98ms/step - loss: 2.0848 - rpn_out_class_loss: 1.8209 - rpn_out_regress_loss: 0.2639 - val_loss: 2.2880 - val_rpn_out_class_loss: 2.0228 - val_rpn_out_regress_loss: 0.2651
# Epoch 12/50
# 1000/1000 [==============================] - 98s 98ms/step - loss: 1.9030 - rpn_out_class_loss: 1.6357 - rpn_out_regress_loss: 0.2673 - val_loss: 1.7792 - val_rpn_out_class_loss: 1.5156 - val_rpn_out_regress_loss: 0.2636
#
# Epoch 00012: loss improved from 3.19977 to 1.90297, saving model to ./models/rpn/rpn.thundernetv1.weights.12-1.90.hdf5
# Epoch 13/50
# 1000/1000 [==============================] - 98s 98ms/step - loss: 1.7667 - rpn_out_class_loss: 1.5081 - rpn_out_regress_loss: 0.2587 - val_loss: 2.7553 - val_rpn_out_class_loss: 2.4553 - val_rpn_out_regress_loss: 0.3000
# Epoch 14/50
# 1000/1000 [==============================] - 98s 98ms/step - loss: 1.7308 - rpn_out_class_loss: 1.4697 - rpn_out_regress_loss: 0.2612 - val_loss: 2.2148 - val_rpn_out_class_loss: 1.9391 - val_rpn_out_regress_loss: 0.2757
# Epoch 15/50
# 1000/1000 [==============================] - 98s 98ms/step - loss: 1.5454 - rpn_out_class_loss: 1.2853 - rpn_out_regress_loss: 0.2602 - val_loss: 2.1392 - val_rpn_out_class_loss: 1.8734 - val_rpn_out_regress_loss: 0.2658
# Epoch 16/50
# 1000/1000 [==============================] - 99s 99ms/step - loss: 1.5504 - rpn_out_class_loss: 1.2900 - rpn_out_regress_loss: 0.2604 - val_loss: 2.6397 - val_rpn_out_class_loss: 2.3487 - val_rpn_out_regress_loss: 0.2910
#
# Epoch 00016: loss improved from 1.90297 to 1.55040, saving model to ./models/rpn/rpn.thundernetv1.weights.16-1.55.hdf5
# Epoch 17/50
# 1000/1000 [==============================] - 99s 99ms/step - loss: 1.3393 - rpn_out_class_loss: 1.0854 - rpn_out_regress_loss: 0.2539 - val_loss: 1.7587 - val_rpn_out_class_loss: 1.4999 - val_rpn_out_regress_loss: 0.2588
# Epoch 18/50
# 1000/1000 [==============================] - 100s 100ms/step - loss: 1.3900 - rpn_out_class_loss: 1.1349 - rpn_out_regress_loss: 0.2551 - val_loss: 2.8204 - val_rpn_out_class_loss: 2.5348 - val_rpn_out_regress_loss: 0.2857
# Epoch 19/50
# 1000/1000 [==============================] - 100s 100ms/step - loss: 1.3368 - rpn_out_class_loss: 1.0785 - rpn_out_regress_loss: 0.2584 - val_loss: 2.1940 - val_rpn_out_class_loss: 1.9324 - val_rpn_out_regress_loss: 0.2616
# Epoch 20/50
# 1000/1000 [==============================] - 100s 100ms/step - loss: 1.2762 - rpn_out_class_loss: 1.0317 - rpn_out_regress_loss: 0.2445 - val_loss: 2.3955 - val_rpn_out_class_loss: 2.0963 - val_rpn_out_regress_loss: 0.2992
#
# Epoch 00020: loss improved from 1.55040 to 1.27616, saving model to ./models/rpn/rpn.thundernetv1.weights.20-1.28.hdf5
# Epoch 21/50
# 1000/1000 [==============================] - 100s 100ms/step - loss: 1.2670 - rpn_out_class_loss: 1.0227 - rpn_out_regress_loss: 0.2442 - val_loss: 2.2416 - val_rpn_out_class_loss: 1.9510 - val_rpn_out_regress_loss: 0.2906
# Epoch 22/50
# 1000/1000 [==============================] - 101s 101ms/step - loss: 1.3701 - rpn_out_class_loss: 1.1126 - rpn_out_regress_loss: 0.2575 - val_loss: 1.8749 - val_rpn_out_class_loss: 1.6113 - val_rpn_out_regress_loss: 0.2636
# Epoch 23/50
# 1000/1000 [==============================] - 101s 101ms/step - loss: 1.2611 - rpn_out_class_loss: 1.0267 - rpn_out_regress_loss: 0.2344 - val_loss: 2.3987 - val_rpn_out_class_loss: 2.1165 - val_rpn_out_regress_loss: 0.2823
# Epoch 24/50
# 1000/1000 [==============================] - 100s 100ms/step - loss: 1.2279 - rpn_out_class_loss: 0.9895 - rpn_out_regress_loss: 0.2383 - val_loss: 1.9760 - val_rpn_out_class_loss: 1.7080 - val_rpn_out_regress_loss: 0.2680
#
# Epoch 00024: loss improved from 1.27616 to 1.22785, saving model to ./models/rpn/rpn.thundernetv1.weights.24-1.23.hdf5
# Epoch 25/50
#   88/1000 [=>............................] - ETA: 1:28 - loss: 1.2430 - rpn_out_class_loss: 0.9935 - rpn_out_regress_loss: 0.2495^C
# Traceback (most recent call last):
#   File "train_rpn.py", line 247, in <module>
#     steps_per_epoch=options.epoch_length, callbacks=callback, validation_steps=100)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/engine/training.py", line 1418, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/engine/training_generator.py", line 217, in fit_generator
#     class_weight=class_weight)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/engine/training.py", line 1217, in train_on_batch
#     outputs = self.train_function(ins)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 2715, in __call__
#     return self._call(inputs)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 2675, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1439, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt

# %%
DATASET = "/home/henri_tomas/projects/faster-rcnn/frcnn-from-scratch-with-keras/2007_2012_trainval.txt"
# !python measure_map.py  --network $BACKBONE -p $TEST_IMAGES --load $MODEL --write -n 4
# Out:
# Using TensorFlow backend.
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-01-15 11:10:34.654918: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-01-15 11:10:36.695435: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-15 11:10:36.696285: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55a7e3fe7720 executing computations on platform CUDA. Devices:
# 2020-01-15 11:10:36.696339: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-01-15 11:10:36.699458: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-01-15 11:10:36.699726: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55a7e40501d0 executing computations on platform Host. Devices:
# 2020-01-15 11:10:36.699759: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-01-15 11:10:36.700248: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2020-01-15 11:10:36.700286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-01-15 11:10:36.701200: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-15 11:10:36.701229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-01-15 11:10:36.701244: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-01-15 11:10:36.701529: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10802 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Usage: measure_map.py [options]
#
# measure_map.py: error: no such option: -o

# %%
#INITIAL TRAINING FRCNN, NOT CONTINUE TRAINING

BACKBONE = "thundernetv1"
DATASET = "/home/henri_tomas/projects/faster-rcnn/frcnn-from-scratch-with-keras/2007_2012_trainval.txt"
RPN = "./models/rpn/rpn.thundernetv1.weights.24-1.23.hdf5"
SAVE_TO = "voc_person_cem_3"
OPT = "adam"

# !python train_frcnn.py --network $BACKBONE -o simple -p $DATASET --rpn $RPN --num_epochs 50 --dataset $SAVE_TO -n 4
# Out:
# Using TensorFlow backend.
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-01-11 22:52:41.321496: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-01-11 22:52:43.333809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-11 22:52:43.334404: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x564dbcef6c90 executing computations on platform CUDA. Devices:
# 2020-01-11 22:52:43.334467: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-01-11 22:52:43.337197: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-01-11 22:52:43.337448: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x564dbcf5f6f0 executing computations on platform Host. Devices:
# 2020-01-11 22:52:43.337481: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-01-11 22:52:43.337799: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2020-01-11 22:52:43.337852: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-01-11 22:52:43.338889: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-11 22:52:43.338932: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-01-11 22:52:43.338946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-01-11 22:52:43.339254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10802 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Parsing annotation files
# Training images per class:
# {'bg': 0, 'person': 13256}
# Num classes (including bg) = 2
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 6095
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# loading weights from ./pretrain/mobilenet_1_0_224_tf.h5
# Using Adam as optimizer with initial lr = 1e-5
# First time training with pretrained RPN.
# loading RPN weights from  ./models/rpn/rpn.thundernetv1.weights.24-1.23.hdf5
# Starting training
# Epoch 1/50
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 2020-01-11 22:53:35.151005: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# 5036/6095 [=======================>......] - ETA: 4:24 - rpn_cls: 1.8641 - rpn_regr: 0.2457 - detector_cls: 0.6282 - detector_regr: 0.3620 - average number of objects: 1.7143Exception: 'a' cannot be empty unless no samples are taken
# 5543/6095 [==========================>...] - ETA: 2:17 - rpn_cls: 1.8541 - rpn_regr: 0.2456 - detector_cls: 0.6249 - detector_regr: 0.3597 - average number of objects: 1.7132Exception: 'a' cannot be empty unless no samples are taken
# 5985/6095 [============================>.] - ETA: 27s - rpn_cls: 1.8457 - rpn_regr: 0.2455 - detector_cls: 0.6220 - detector_regr: 0.3578 - average number of objects: 1.7158Average number of overlapping bounding boxes from RPN = 3.64856439704676 for 6095 previous iterations
# 6095/6095 [==============================] - 1517s 249ms/step - rpn_cls: 1.8437 - rpn_regr: 0.2454 - detector_cls: 0.6213 - detector_regr: 0.3574 - average number of objects: 1.7155
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.646698872785829
# Classifier accuracy for bounding boxes from RPN: 0.697005742411813
# Loss RPN classifier: 1.7316673194566121
# Loss RPN regression: 0.24392284959317068
# Loss Detector classifier: 0.5827653767084175
# Loss Detector regression: 0.3328385986443884
# Elapsed time: 1517.0331063270569
# Total loss decreased from inf to 2.8911941444025886, saving weights
# Epoch 2/50
#  483/6095 [=>............................] - ETA: 23:14 - rpn_cls: 1.4469 - rpn_regr: 0.2382 - detector_cls: 0.5442 - detector_regr: 0.3061 - average number of objects: 1.7246Exception: 'a' cannot be empty unless no samples are taken
# 2214/6095 [=========>....................] - ETA: 16:00 - rpn_cls: 1.5828 - rpn_regr: 0.2392 - detector_cls: 0.5243 - detector_regr: 0.2969 - average number of objects: 1.7218Exception: 'a' cannot be empty unless no samples are taken
# 2221/6095 [=========>....................] - ETA: 15:59 - rpn_cls: 1.5830 - rpn_regr: 0.2392 - detector_cls: 0.5242 - detector_regr: 0.2969 - average number of objects: 1.7217Exception: 'a' cannot be empty unless no samples are taken
# 2822/6095 [============>.................] - ETA: 13:31 - rpn_cls: 1.5959 - rpn_regr: 0.2398 - detector_cls: 0.5199 - detector_regr: 0.2960 - average number of objects: 1.7208Exception: 'a' cannot be empty unless no samples are taken
# 5867/6095 [===========================>..] - ETA: 56s - rpn_cls: 1.6021 - rpn_regr: 0.2391 - detector_cls: 0.5084 - detector_regr: 0.2949 - average number of objects: 1.7394Average number of overlapping bounding boxes from RPN = 3.7822805578342904 for 6095 previous iterations
# 6095/6095 [==============================] - 1511s 248ms/step - rpn_cls: 1.6011 - rpn_regr: 0.2389 - detector_cls: 0.5077 - detector_regr: 0.2948 - average number of objects: 1.7398
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.812047028507006
# Classifier accuracy for bounding boxes from RPN: 0.7671862182116489
# Loss RPN classifier: 1.572282145159264
# Loss RPN regression: 0.23355593360351953
# Loss Detector classifier: 0.49044810918108594
# Loss Detector regression: 0.2930388717694396
# Elapsed time: 1521.9425263404846
# Total loss decreased from 2.8911941444025886 to 2.589325059713309, saving weights
# Epoch 3/50
# 1200/6095 [====>.........................] - ETA: 20:12 - rpn_cls: 1.3388 - rpn_regr: 0.2355 - detector_cls: 0.4769 - detector_regr: 0.2870 - average number of objects: 1.7483Exception: 'a' cannot be empty unless no samples are taken
# 5772/6095 [===========================>..] - ETA: 1:20 - rpn_cls: 1.4573 - rpn_regr: 0.2313 - detector_cls: 0.4642 - detector_regr: 0.2849 - average number of objects: 1.7500Average number of overlapping bounding boxes from RPN = 3.9061525840853157 for 6095 previous iterations
# 5976/6095 [============================>.] - ETA: 29s - rpn_cls: 1.4575 - rpn_regr: 0.2311 - detector_cls: 0.4639 - detector_regr: 0.2848 - average number of objects: 1.7530Exception: 'a' cannot be empty unless no samples are taken
# 6095/6095 [==============================] - 1515s 249ms/step - rpn_cls: 1.4576 - rpn_regr: 0.2311 - detector_cls: 0.4638 - detector_regr: 0.2848 - average number of objects: 1.7516
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.893122376493381
# Classifier accuracy for bounding boxes from RPN: 0.7917145200984413
# Loss RPN classifier: 1.4591074880113335
# Loss RPN regression: 0.22731139425469457
# Loss Detector classifier: 0.4547168729057455
# Loss Detector regression: 0.2821518005119443
# Elapsed time: 1515.054514169693
# Total loss decreased from 2.589325059713309 to 2.4232875556837175, saving weights
# Epoch 4/50
# 5668/6095 [==========================>...] - ETA: 1:50 - rpn_cls: 2.1882 - rpn_regr: 0.2613 - detector_cls: 0.5846 - detector_regr: 0.3696 - average number of objects: 1.6953Average number of overlapping bounding boxes from RPN = 3.821985233798195 for 6095 previous iterations
# 6095/6095 [==============================] - 1579s 259ms/step - rpn_cls: 2.1887 - rpn_regr: 0.2610 - detector_cls: 0.5808 - detector_regr: 0.3673 - average number of objects: 1.6957
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.813195676722052
# Classifier accuracy for bounding boxes from RPN: 0.7688269073010664
# Loss RPN classifier: 2.1821959364297157
# Loss RPN regression: 0.2578641786065084
# Loss Detector classifier: 0.5281746651353574
# Loss Detector regression: 0.33510344761686967
# Elapsed time: 1578.9112117290497
# Epoch 5/50
#  971/6095 [===>..........................] - ETA: 22:35 - rpn_cls: 2.0061 - rpn_regr: 0.2461 - detector_cls: 0.4831 - detector_regr: 0.3128 - average number of objects: 1.7137Exception: 'a' cannot be empty unless no samples are taken
# 5577/6095 [==========================>...] - ETA: 2:15 - rpn_cls: 1.8810 - rpn_regr: 0.2370 - detector_cls: 0.4703 - detector_regr: 0.3008 - average number of objects: 1.7264Average number of overlapping bounding boxes from RPN = 3.895980311730927 for 6095 previous iterations
# 6095/6095 [==============================] - 1595s 262ms/step - rpn_cls: 1.8731 - rpn_regr: 0.2365 - detector_cls: 0.4692 - detector_regr: 0.3000 - average number of objects: 1.7288
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.9229899903132064
# Classifier accuracy for bounding boxes from RPN: 0.8089417555373257
# Loss RPN classifier: 1.7866492978440753
# Loss RPN regression: 0.23051112266175275
# Loss Detector classifier: 0.45660918828005503
# Loss Detector regression: 0.29125027308857276
# Elapsed time: 1595.125875711441
# Epoch 6/50
#  493/6095 [=>............................] - ETA: 24:24 - rpn_cls: 1.5987 - rpn_regr: 0.2295 - detector_cls: 0.4347 - detector_regr: 0.2958 - average number of objects: 1.7546Exception: 'a' cannot be empty unless no samples are taken
#  981/6095 [===>..........................] - ETA: 22:23 - rpn_cls: 1.6651 - rpn_regr: 0.2280 - detector_cls: 0.4373 - detector_regr: 0.2853 - average number of objects: 1.7350Exception: 'a' cannot be empty unless no samples are taken
# 1410/6095 [=====>........................] - ETA: 20:32 - rpn_cls: 1.6689 - rpn_regr: 0.2270 - detector_cls: 0.4382 - detector_regr: 0.2834 - average number of objects: 1.7220Exception: 'a' cannot be empty unless no samples are taken
# 5466/6095 [=========================>....] - ETA: 2:46 - rpn_cls: 1.6184 - rpn_regr: 0.2213 - detector_cls: 0.4402 - detector_regr: 0.2794 - average number of objects: 1.7477Average number of overlapping bounding boxes from RPN = 4.016570959803118 for 6095 previous iterations
# 6095/6095 [==============================] - 1616s 265ms/step - rpn_cls: 1.6144 - rpn_regr: 0.2207 - detector_cls: 0.4401 - detector_regr: 0.2793 - average number of objects: 1.7467
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.017088505561825
# Classifier accuracy for bounding boxes from RPN: 0.8253486464315012
# Loss RPN classifier: 1.5750696938916353
# Loss RPN regression: 0.2155911880118812
# Loss Detector classifier: 0.43878090351699683
# Loss Detector regression: 0.2787138025395548
# Elapsed time: 1616.3572192192078
# Epoch 7/50
#  582/6095 [=>............................] - ETA: 25:01 - rpn_cls: 1.4226 - rpn_regr: 0.2185 - detector_cls: 0.4529 - detector_regr: 0.2600 - average number of objects: 1.7285Exception: 'a' cannot be empty unless no samples are taken
#  634/6095 [==>...........................] - ETA: 24:47 - rpn_cls: 1.4218 - rpn_regr: 0.2179 - detector_cls: 0.4516 - detector_regr: 0.2599 - average number of objects: 1.7397Exception: 'a' cannot be empty unless no samples are taken
# 1578/6095 [======>.......................] - ETA: 20:26 - rpn_cls: 1.4049 - rpn_regr: 0.2121 - detector_cls: 0.4374 - detector_regr: 0.2624 - average number of objects: 1.7471Exception: 'a' cannot be empty unless no samples are taken
# 4302/6095 [====================>.........] - ETA: 8:03 - rpn_cls: 1.4117 - rpn_regr: 0.2104 - detector_cls: 0.4253 - detector_regr: 0.2632 - average number of objects: 1.7510Exception: 'a' cannot be empty unless no samples are taken
# 5349/6095 [=========================>....] - ETA: 3:21 - rpn_cls: 1.4178 - rpn_regr: 0.2099 - detector_cls: 0.4235 - detector_regr: 0.2626 - average number of objects: 1.7491Average number of overlapping bounding boxes from RPN = 4.056439704675964 for 6095 previous iterations
# 5949/6095 [============================>.] - ETA: 39s - rpn_cls: 1.4208 - rpn_regr: 0.2097 - detector_cls: 0.4228 - detector_regr: 0.2623 - average number of objects: 1.7480Exception: 'a' cannot be empty unless no samples are taken
# 6095/6095 [==============================] - 1646s 270ms/step - rpn_cls: 1.4214 - rpn_regr: 0.2097 - detector_cls: 0.4226 - detector_regr: 0.2623 - average number of objects: 1.7482
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.035582031878924
# Classifier accuracy for bounding boxes from RPN: 0.8403199343724365
# Loss RPN classifier: 1.4463721473292674
# Loss RPN regression: 0.20727576926993121
# Loss Detector classifier: 0.4154288629972128
# Loss Detector regression: 0.2600407585341516
# Elapsed time: 1646.1844761371613
# Total loss decreased from 2.4232875556837175 to 2.329117538130563, saving weights
# Epoch 8/50
# 5249/6095 [========================>.....] - ETA: 3:50 - rpn_cls: 1.4730 - rpn_regr: 0.1984 - detector_cls: 0.4016 - detector_regr: 0.2509 - average number of objects: 1.7525Average number of overlapping bounding boxes from RPN = 4.051025430680886 for 6095 previous iterations
# 5698/6095 [===========================>..] - ETA: 1:48 - rpn_cls: 1.4707 - rpn_regr: 0.1985 - detector_cls: 0.4021 - detector_regr: 0.2507 - average number of objects: 1.7517Exception: 'a' cannot be empty unless no samples are taken
# 6095/6095 [==============================] - 1664s 273ms/step - rpn_cls: 1.4688 - rpn_regr: 0.1985 - detector_cls: 0.4025 - detector_regr: 0.2505 - average number of objects: 1.7529
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.057884553369881
# Classifier accuracy for bounding boxes from RPN: 0.8417965545529122
# Loss RPN classifier: 1.4323573854136997
# Loss RPN regression: 0.19764724019487023
# Loss Detector classifier: 0.4077181323952669
# Loss Detector regression: 0.24755482269297313
# Elapsed time: 1663.930133342743
# Total loss decreased from 2.329117538130563 to 2.2852775806968095, saving weights
# Epoch 9/50
# 1326/6095 [=====>........................] - ETA: 22:06 - rpn_cls: 1.2892 - rpn_regr: 0.1920 - detector_cls: 0.4026 - detector_regr: 0.2384 - average number of objects: 1.7738Exception: 'a' cannot be empty unless no samples are taken
# 5006/6095 [=======================>......] - ETA: 5:03 - rpn_cls: 1.3364 - rpn_regr: 0.1903 - detector_cls: 0.4032 - detector_regr: 0.2388 - average number of objects: 1.7555Exception: 'a' cannot be empty unless no samples are taken
# 5139/6095 [========================>.....] - ETA: 4:26 - rpn_cls: 1.3367 - rpn_regr: 0.1903 - detector_cls: 0.4033 - detector_regr: 0.2388 - average number of objects: 1.7558Average number of overlapping bounding boxes from RPN = 4.095980311730927 for 6095 previous iterations
# 6095/6095 [==============================] - 1704s 280ms/step - rpn_cls: 1.3382 - rpn_regr: 0.1907 - detector_cls: 0.4038 - detector_regr: 0.2388 - average number of objects: 1.7580
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.131570461141568
# Classifier accuracy for bounding boxes from RPN: 0.8461033634126333
# Loss RPN classifier: 1.3485061853322615
# Loss RPN regression: 0.192886870837953
# Loss Detector classifier: 0.40588311330495414
# Loss Detector regression: 0.23805947919170678
# Elapsed time: 1704.0391085147858
# Total loss decreased from 2.2852775806968095 to 2.185335648666875, saving weights
# Epoch 10/50
#   10/6095 [..............................] - ETA: 28:16 - rpn_cls: 1.9799 - rpn_regr: 0.2140 - detector_cls: 0.7922 - detector_regr: 0.3162 - average number of objects: 1.5000Exception: 'a' cannot be empty unless no samples are taken
# 5028/6095 [=======================>......] - ETA: 5:06 - rpn_cls: 1.2726 - rpn_regr: 0.1829 - detector_cls: 0.3936 - detector_regr: 0.2336 - average number of objects: 1.7605Average number of overlapping bounding boxes from RPN = 4.118949958982773 for 6095 previous iterations
# 6095/6095 [==============================] - 1762s 289ms/step - rpn_cls: 1.2756 - rpn_regr: 0.1832 - detector_cls: 0.3922 - detector_regr: 0.2329 - average number of objects: 1.7608
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.0641891891891895
# Classifier accuracy for bounding boxes from RPN: 0.8614438063986875
# Loss RPN classifier: 1.2947352611627656
# Loss RPN regression: 0.1842426882653174
# Loss Detector classifier: 0.3836970680851294
# Loss Detector regression: 0.22832599630463987
# Elapsed time: 1762.327832698822
# Total loss decreased from 2.185335648666875 to 2.0910010138178525, saving weights
# Epoch 11/50
# 3781/6095 [=================>............] - ETA: 11:18 - rpn_cls: 1.3805 - rpn_regr: 0.1792 - detector_cls: 0.3823 - detector_regr: 0.2215 - average number of objects: 1.7625Exception: 'a' cannot be empty unless no samples are taken
# 3985/6095 [==================>...........] - ETA: 10:19 - rpn_cls: 1.3754 - rpn_regr: 0.1791 - detector_cls: 0.3826 - detector_regr: 0.2218 - average number of objects: 1.7651Exception: 'a' cannot be empty unless no samples are taken
# 4929/6095 [=======================>......] - ETA: 5:42 - rpn_cls: 1.3553 - rpn_regr: 0.1789 - detector_cls: 0.3840 - detector_regr: 0.2227 - average number of objects: 1.7699Average number of overlapping bounding boxes from RPN = 4.102214930270714 for 6095 previous iterations
# 6095/6095 [==============================] - 1791s 294ms/step - rpn_cls: 1.3400 - rpn_regr: 0.1787 - detector_cls: 0.3846 - detector_regr: 0.2232 - average number of objects: 1.7675
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.124454501373848
# Classifier accuracy for bounding boxes from RPN: 0.8611156685808039
# Loss RPN classifier: 1.2673116853024116
# Loss RPN regression: 0.1771552750973147
# Loss Detector classifier: 0.38712853829661314
# Loss Detector regression: 0.22416779399133985
# Elapsed time: 1790.9130990505219
# Total loss decreased from 2.0910010138178525 to 2.055763292687679, saving weights
# Epoch 12/50
# 4819/6095 [======================>.......] - ETA: 6:13 - rpn_cls: 1.2490 - rpn_regr: 0.1741 - detector_cls: 0.3763 - detector_regr: 0.2187 - average number of objects: 1.7726Average number of overlapping bounding boxes from RPN = 4.117309269893355 for 6095 previous iterations
# 6095/6095 [==============================] - 1792s 294ms/step - rpn_cls: 1.2436 - rpn_regr: 0.1739 - detector_cls: 0.3772 - detector_regr: 0.2186 - average number of objects: 1.7667
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.1406929895245765
# Classifier accuracy for bounding boxes from RPN: 0.8658736669401148
# Loss RPN classifier: 1.2242047720003288
# Loss RPN regression: 0.17329711382079815
# Loss Detector classifier: 0.3789298286550941
# Loss Detector regression: 0.2169699168371738
# Elapsed time: 1792.2903203964233
# Total loss decreased from 2.055763292687679 to 1.9934016313133949, saving weights
# Epoch 13/50
#  102/6095 [..............................] - ETA: 29:28 - rpn_cls: 1.0538 - rpn_regr: 0.1962 - detector_cls: 0.3909 - detector_regr: 0.2078 - average number of objects: 1.8333Exception: 'a' cannot be empty unless no samples are taken
# 2202/6095 [=========>....................] - ETA: 19:00 - rpn_cls: 1.1435 - rpn_regr: 0.1746 - detector_cls: 0.3828 - detector_regr: 0.2139 - average number of objects: 1.7788Exception: 'a' cannot be empty unless no samples are taken
# 4722/6095 [======================>.......] - ETA: 6:44 - rpn_cls: 1.1782 - rpn_regr: 0.1726 - detector_cls: 0.3776 - detector_regr: 0.2120 - average number of objects: 1.7698Average number of overlapping bounding boxes from RPN = 4.100574241181296 for 6095 previous iterations
# 5006/6095 [=======================>......] - ETA: 5:20 - rpn_cls: 1.1797 - rpn_regr: 0.1724 - detector_cls: 0.3772 - detector_regr: 0.2118 - average number of objects: 1.7697Exception: 'a' cannot be empty unless no samples are taken
# 5293/6095 [=========================>....] - ETA: 3:56 - rpn_cls: 1.1811 - rpn_regr: 0.1723 - detector_cls: 0.3766 - detector_regr: 0.2117 - average number of objects: 1.7678Exception: 'a' cannot be empty unless no samples are taken
# 5446/6095 [=========================>....] - ETA: 3:11 - rpn_cls: 1.1817 - rpn_regr: 0.1722 - detector_cls: 0.3764 - detector_regr: 0.2116 - average number of objects: 1.7657Exception: 'a' cannot be empty unless no samples are taken
# 6095/6095 [==============================] - 1796s 295ms/step - rpn_cls: 1.1823 - rpn_regr: 0.1719 - detector_cls: 0.3751 - detector_regr: 0.2112 - average number of objects: 1.7657
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.052368675475346
# Classifier accuracy for bounding boxes from RPN: 0.8763330598851518
# Loss RPN classifier: 1.175965903060047
# Loss RPN regression: 0.1698226191777693
# Loss Detector classifier: 0.36578104846187376
# Loss Detector regression: 0.2080818770490006
# Elapsed time: 1795.8596467971802
# Total loss decreased from 1.9934016313133949 to 1.9196514477486906, saving weights
# Epoch 14/50
#  105/6095 [..............................] - ETA: 28:52 - rpn_cls: 1.6653 - rpn_regr: 0.1927 - detector_cls: 0.4143 - detector_regr: 0.2129 - average number of objects: 1.7714^C
# Traceback (most recent call last):
#   File "train_frcnn.py", line 299, in <module>
#     X2, Y1, Y2, IouS = roi_helpers.calc_iou(R, img_data, C, class_mapping)
#   File "/home/henri_tomas/projects/faster-rcnn/frcnn-from-scratch-with-keras/keras_frcnn/roi_helpers.py", line 40, in calc_iou
#     curr_iou = data_generators.iou([gta[bbox_num, 0], gta[bbox_num, 2], gta[bbox_num, 1], gta[bbox_num, 3]], [x1, y1, x2, y2])
# KeyboardInterrupt

# %%
# CONTINUE TRAINING
BACKBONE = "thundernetv1"
DATASET = "/home/henri_tomas/projects/faster-rcnn/frcnn-from-scratch-with-keras/2007_2012_trainval.txt"
SAVE_TO = "voc_person_cem_3"
MODEL = "./models/thundernetv1/voc_person_cem_3.hdf5"

# !python train_frcnn.py --network $BACKBONE -o simple -p $DATASET --num_epochs 10 --dataset $SAVE_TO -n 4 --load $MODEL
# Out:
# Using TensorFlow backend.
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-01-15 08:32:27.538004: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-01-15 08:32:30.680711: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-15 08:32:30.697298: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55846af1e380 executing computations on platform CUDA. Devices:
# 2020-01-15 08:32:30.697340: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-01-15 08:32:31.151419: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-01-15 08:32:31.151700: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x55846af86df0 executing computations on platform Host. Devices:
# 2020-01-15 08:32:31.151751: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-01-15 08:32:31.152177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2020-01-15 08:32:31.152233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-01-15 08:32:31.172638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-15 08:32:31.172673: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-01-15 08:32:31.172688: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-01-15 08:32:31.173085: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10802 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Parsing annotation files
# Training images per class:
# {'bg': 0, 'person': 13256}
# Num classes (including bg) = 2
# Config has been written to config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 6095
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# loading weights from ./pretrain/mobilenet_1_0_224_tf.h5
# Using Adam as optimizer with initial lr = 1e-5
# loading previous model from  ./models/thundernetv1/voc_person_cem_3.hdf5
# Already train 30K batches
# Starting training
# Epoch 31/40
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 2020-01-15 08:34:39.410027: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# 1158/6095 [====>.........................] - ETA: 24:23 - rpn_cls: 0.5046 - rpn_regr: 0.1133 - detector_cls: 0.2914 - detector_regr: 0.1513 - average number of objects: 1.7763Exception: 'a' cannot be empty unless no samples are taken
# 1290/6095 [=====>........................] - ETA: 23:22 - rpn_cls: 0.4968 - rpn_regr: 0.1132 - detector_cls: 0.2896 - detector_regr: 0.1507 - average number of objects: 1.7659Exception: 'a' cannot be empty unless no samples are taken
# 2553/6095 [===========>..................] - ETA: 15:58 - rpn_cls: 0.4789 - rpn_regr: 0.1110 - detector_cls: 0.2850 - detector_regr: 0.1477 - average number of objects: 1.7575Exception: 'a' cannot be empty unless no samples are taken
# 3075/6095 [==============>...............] - ETA: 13:27 - rpn_cls: 0.4777 - rpn_regr: 0.1107 - detector_cls: 0.2841 - detector_regr: 0.1473 - average number of objects: 1.7574Exception: 'a' cannot be empty unless no samples are taken
# 3399/6095 [===============>..............] - ETA: 11:56 - rpn_cls: 0.4772 - rpn_regr: 0.1105 - detector_cls: 0.2836 - detector_regr: 0.1473 - average number of objects: 1.7570Exception: 'a' cannot be empty unless no samples are taken
# 6006/6095 [============================>.] - ETA: 23s - rpn_cls: 0.4782 - rpn_regr: 0.1103 - detector_cls: 0.2797 - detector_regr: 0.1468 - average number of objects: 1.7657Average number of overlapping bounding boxes from RPN = 4.009844134536506 for 6095 previous iterations
# 6095/6095 [==============================] - 1592s 261ms/step - rpn_cls: 0.4783 - rpn_regr: 0.1103 - detector_cls: 0.2796 - detector_regr: 0.1468 - average number of objects: 1.7634
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.009054163298303
# Classifier accuracy for bounding boxes from RPN: 0.9117309269893356
# Loss RPN classifier: 0.48719530804217176
# Loss RPN regression: 0.1111044050185346
# Loss Detector classifier: 0.27459090212813914
# Loss Detector regression: 0.14631276333627138
# Elapsed time: 1592.3752853870392
# Total loss decreased from inf to 1.0192033785251169, saving weights
# Epoch 32/40
# 1085/6095 [====>.........................] - ETA: 21:30 - rpn_cls: 0.5177 - rpn_regr: 0.1110 - detector_cls: 0.2988 - detector_regr: 0.1415 - average number of objects: 1.7650Exception: 'a' cannot be empty unless no samples are taken
# 1484/6095 [======>.......................] - ETA: 19:48 - rpn_cls: 0.5122 - rpn_regr: 0.1112 - detector_cls: 0.2968 - detector_regr: 0.1418 - average number of objects: 1.7635Exception: 'a' cannot be empty unless no samples are taken
# 3454/6095 [================>.............] - ETA: 11:23 - rpn_cls: 0.5002 - rpn_regr: 0.1115 - detector_cls: 0.2882 - detector_regr: 0.1432 - average number of objects: 1.7539Exception: 'a' cannot be empty unless no samples are taken
# 5051/6095 [=======================>......] - ETA: 4:29 - rpn_cls: 0.4998 - rpn_regr: 0.1114 - detector_cls: 0.2854 - detector_regr: 0.1438 - average number of objects: 1.7656Exception: 'a' cannot be empty unless no samples are taken
# 5913/6095 [============================>.] - ETA: 47s - rpn_cls: 0.4991 - rpn_regr: 0.1112 - detector_cls: 0.2847 - detector_regr: 0.1440 - average number of objects: 1.7675Average number of overlapping bounding boxes from RPN = 4.0105004101722725 for 6095 previous iterations
# 6095/6095 [==============================] - 1578s 259ms/step - rpn_cls: 0.4989 - rpn_regr: 0.1112 - detector_cls: 0.2846 - detector_regr: 0.1440 - average number of objects: 1.7651
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.001616292225634
# Classifier accuracy for bounding boxes from RPN: 0.9101722723543888
# Loss RPN classifier: 0.49273230807247387
# Loss RPN regression: 0.11017212467672077
# Loss Detector classifier: 0.2797908800759267
# Loss Detector regression: 0.14462788689665593
# Elapsed time: 1591.074544429779
# Epoch 33/40
# 5824/6095 [===========================>..] - ETA: 1:11 - rpn_cls: 0.4813 - rpn_regr: 0.1090 - detector_cls: 0.2882 - detector_regr: 0.1421 - average number of objects: 1.7625Average number of overlapping bounding boxes from RPN = 3.9665299425758818 for 6095 previous iterations
# 6095/6095 [==============================] - 1615s 265ms/step - rpn_cls: 0.4811 - rpn_regr: 0.1090 - detector_cls: 0.2878 - detector_regr: 0.1421 - average number of objects: 1.7642
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.9806076276664513
# Classifier accuracy for bounding boxes from RPN: 0.9099261689909762
# Loss RPN classifier: 0.4785971290919852
# Loss RPN regression: 0.10821225647329906
# Loss Detector classifier: 0.2806399211460333
# Loss Detector regression: 0.14221097407898595
# Elapsed time: 1614.9671025276184
# Total loss decreased from 1.0192033785251169 to 1.0096602807903035, saving weights
# Epoch 34/40
#  453/6095 [=>............................] - ETA: 24:57 - rpn_cls: 0.4891 - rpn_regr: 0.1160 - detector_cls: 0.2935 - detector_regr: 0.1518 - average number of objects: 1.7815Exception: 'a' cannot be empty unless no samples are taken
# 1109/6095 [====>.........................] - ETA: 22:04 - rpn_cls: 0.4823 - rpn_regr: 0.1104 - detector_cls: 0.2833 - detector_regr: 0.1480 - average number of objects: 1.7818Exception: 'a' cannot be empty unless no samples are taken
# 1905/6095 [========>.....................] - ETA: 18:29 - rpn_cls: 0.4781 - rpn_regr: 0.1089 - detector_cls: 0.2815 - detector_regr: 0.1475 - average number of objects: 1.7633Exception: 'a' cannot be empty unless no samples are taken
# 4460/6095 [====================>.........] - ETA: 7:12 - rpn_cls: 0.4716 - rpn_regr: 0.1091 - detector_cls: 0.2800 - detector_regr: 0.1443 - average number of objects: 1.7522Exception: 'a' cannot be empty unless no samples are taken
# 5745/6095 [===========================>..] - ETA: 1:32 - rpn_cls: 0.4673 - rpn_regr: 0.1091 - detector_cls: 0.2795 - detector_regr: 0.1437 - average number of objects: 1.7506Average number of overlapping bounding boxes from RPN = 3.976702214930271 for 6095 previous iterations
# 6095/6095 [==============================] - 1614s 265ms/step - rpn_cls: 0.4668 - rpn_regr: 0.1090 - detector_cls: 0.2793 - detector_regr: 0.1435 - average number of objects: 1.7518
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 3.982353893475797
# Classifier accuracy for bounding boxes from RPN: 0.9135356849876949
# Loss RPN classifier: 0.4595425401302797
# Loss RPN regression: 0.10821566542685399
# Loss Detector classifier: 0.2745900403616077
# Loss Detector regression: 0.14172400947039168
# Elapsed time: 1614.6029708385468
# Total loss decreased from 1.0096602807903035 to 0.984072255389133, saving weights
# Epoch 35/40
#   87/6095 [..............................] - ETA: 26:18 - rpn_cls: 0.4584 - rpn_regr: 0.1375 - detector_cls: 0.2675 - detector_regr: 0.1576 - average number of objects: 1.7126Exception: 'a' cannot be empty unless no samples are taken
# 1908/6095 [========>.....................] - ETA: 18:37 - rpn_cls: 0.4487 - rpn_regr: 0.1117 - detector_cls: 0.2887 - detector_regr: 0.1416 - average number of objects: 1.7568Exception: 'a' cannot be empty unless no samples are taken
# 2309/6095 [==========>...................] - ETA: 16:51 - rpn_cls: 0.4425 - rpn_regr: 0.1109 - detector_cls: 0.2877 - detector_regr: 0.1417 - average number of objects: 1.7575Exception: 'a' cannot be empty unless no samples are taken
# 3053/6095 [==============>...............] - ETA: 13:33 - rpn_cls: 0.4381 - rpn_regr: 0.1097 - detector_cls: 0.2848 - detector_regr: 0.1418 - average number of objects: 1.7619Exception: 'a' cannot be empty unless no samples are taken
# 5657/6095 [==========================>...] - ETA: 1:57 - rpn_cls: 0.4354 - rpn_regr: 0.1080 - detector_cls: 0.2770 - detector_regr: 0.1416 - average number of objects: 1.7661Average number of overlapping bounding boxes from RPN = 4.02247744052502 for 6095 previous iterations
# 6095/6095 [==============================] - 1638s 269ms/step - rpn_cls: 0.4355 - rpn_regr: 0.1078 - detector_cls: 0.2762 - detector_regr: 0.1416 - average number of objects: 1.7662
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 4.009548470626315
# Classifier accuracy for bounding boxes from RPN: 0.9171041837571781
# Loss RPN classifier: 0.4327810982079686
# Loss RPN regression: 0.10528420037422602
# Loss Detector classifier: 0.26664239238922843
# Loss Detector regression: 0.1411203190403093
# Elapsed time: 1638.942673444748
# Total loss decreased from 0.984072255389133 to 0.9458280100117323, saving weights
# Epoch 36/40
#  546/6095 [=>............................] - ETA: 25:02 - rpn_cls: 0.6641 - rpn_regr: 0.1098 - detector_cls: 0.3016 - detector_regr: 0.1398 - average number of objects: 1.7326Exception: 'a' cannot be empty unless no samples are taken
# 2023/6095 [========>.....................] - ETA: 18:33 - rpn_cls: 0.5549 - rpn_regr: 0.1086 - detector_cls: 0.2926 - detector_regr: 0.1416 - average number of objects: 1.7444Exception: 'a' cannot be empty unless no samples are taken
# 2887/6095 [=============>................] - ETA: 14:44 - rpn_cls: 0.5320 - rpn_regr: 0.1080 - detector_cls: 0.2905 - detector_regr: 0.1412 - average number of objects: 1.7516^C
# Traceback (most recent call last):
#   File "train_frcnn.py", line 341, in <module>
#     loss_class = model_classifier.train_on_batch([X, X2[:, sel_samples, :]], [Y1[:, sel_samples, :], Y2[:, sel_samples, :]])
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/engine/training.py", line 1217, in train_on_batch
#     outputs = self.train_function(ins)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 2715, in __call__
#     return self._call(inputs)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 2675, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 1439, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt

# %%
#TEST ON TEST_IMAGES

BACKBONE = "thundernetv1"
TEST_IMAGES = "./test_images/"
MODEL = "./models/thundernetv1/voc_person_cem_3.hdf5"
# !python test_frcnn.py --network $BACKBONE -p $TEST_IMAGES --load $MODEL --write -n 4
# Out:
# Using TensorFlow backend.
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-01-15 11:01:54.107652: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-01-15 11:01:56.142017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-15 11:01:56.142681: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x563221255ce0 executing computations on platform CUDA. Devices:
# 2020-01-15 11:01:56.142714: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-01-15 11:01:56.145505: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-01-15 11:01:56.145773: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x5632212be760 executing computations on platform Host. Devices:
# 2020-01-15 11:01:56.145825: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-01-15 11:01:56.146229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2020-01-15 11:01:56.146265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-01-15 11:01:56.147201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-15 11:01:56.147231: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-01-15 11:01:56.147269: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-01-15 11:01:56.147595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10802 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# {0: 'person', 1: 'bg'}
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Loading weights from ./models/thundernetv1/voc_person_cem_3.hdf5
# 000023.jpg
# (1, 320, 320, 3)
# 2020-01-15 11:02:01.928271: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# Full inference = 1.5734713077545166
# [('person', 97.42122888565063), ('person', 96.24330401420593)]
# {'person': [[112, 0, 240, 304], [0, 0, 112, 272]]}
# 000032.jpg
# (1, 320, 320, 3)
# Full inference = 0.338564395904541
# [('person', 94.3282961845398)]
# {'person': [[112, 112, 160, 240]]}
# dog.jpg
# (1, 320, 320, 3)
# Full inference = 0.27454233169555664
# [('person', 85.82247495651245)]
# {'person': [[32, 48, 192, 304]]}
# dog2.jpg
# (1, 320, 320, 3)
# Full inference = 0.3178112506866455
# [('person', 97.38300442695618), ('person', 90.43338298797607)]
# {'person': [[160, 32, 304, 288], [64, 48, 224, 304]]}
# fns.JPG
# (1, 320, 320, 3)
# Full inference = 0.7184319496154785
# [('person', 99.84887838363647), ('person', 99.49743747711182), ('person', 98.84437918663025), ('person', 98.05541038513184), ('person', 96.9977617263794), ('person', 96.3161289691925), ('person', 94.62042450904846), ('person', 86.2738311290741)]
# {'person': [[160, 80, 176, 192], [208, 96, 240, 192], [16, 64, 48, 208], [128, 80, 144, 144], [256, 96, 288, 192], [80, 80, 112, 176], [144, 96, 176, 256], [32, 112, 48, 192]]}
# person.jpg
# (1, 320, 320, 3)
# Full inference = 0.29076719284057617
# [('person', 99.99381303787231)]
# {'person': [[96, 48, 272, 304]]}
# person2.jpg
# (1, 320, 320, 3)
# Full inference = 0.2567436695098877
# [('person', 99.94920492172241), ('person', 99.92958307266235), ('person', 83.64853262901306)]
# {'person': [[0, 32, 112, 304], [112, 32, 304, 304], [80, 48, 160, 304]]}
# person3.jpg
# (1, 320, 320, 3)
# Full inference = 0.24877166748046875
# [('person', 99.99704360961914), ('person', 99.9174416065216), ('person', 99.9079942703247), ('person', 95.8773672580719)]
# {'person': [[64, 64, 112, 240], [160, 64, 208, 224], [224, 64, 256, 256], [112, 64, 144, 128]]}
# pewdipie.jpg
# (1, 320, 320, 3)
# Full inference = 0.272524356842041
# [('person', 99.90229606628418)]
# {'person': [[48, 0, 160, 304]]}

# %%
#SAVE MODELS TO H5 WITH CORRECT, CONSTANT INPUT_SHAPES !!! 

BACKBONE = "thundernetv1"
TEST_IMAGES = "./test_images/"
MODEL = "./models/thundernetv1/voc_person_rpn.hdf5"
# !python tflite_convert.py --network $BACKBONE -p $TEST_IMAGES --load $MODEL --write -n 4
# Out:
# Using TensorFlow backend.
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-01-09 23:00:19.381978: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-01-09 23:00:21.385195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-01-09 23:00:21.385948: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x562b40a8e190 executing computations on platform CUDA. Devices:
# 2020-01-09 23:00:21.385986: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-01-09 23:00:21.389662: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2020-01-09 23:00:21.389861: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x562b40af6c10 executing computations on platform Host. Devices:
# 2020-01-09 23:00:21.389897: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2020-01-09 23:00:21.390268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2020-01-09 23:00:21.390329: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2020-01-09 23:00:21.391507: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-01-09 23:00:21.391550: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2020-01-09 23:00:21.391575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2020-01-09 23:00:21.391917: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10802 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# {0: 'person', 1: 'bg'}
# backbone is not resnet50. number of features chosen is 512
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Traceback (most recent call last):
#   File "tflite_convert.py", line 167, in <module>
#     classifier = nn.classifier(feature_map_input, roi_input, C.num_rois, nb_classes=len(class_mapping))
#   File "/home/henri_tomas/projects/faster-rcnn/frcnn-from-scratch-with-keras/keras_frcnn/thundernetv1.py", line 198, in classifier
#     x_sam = spatial_attention_module(base_layers)
#   File "/home/henri_tomas/projects/faster-rcnn/frcnn-from-scratch-with-keras/keras_frcnn/thundernetv1.py", line 71, in spatial_attention_module
#     x = layers.multiply([x, base_layers])
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/layers/merge.py", line 596, in multiply
#     return Multiply(**kwargs)(inputs)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/engine/base_layer.py", line 431, in __call__
#     self.build(unpack_singleton(input_shapes))
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/layers/merge.py", line 91, in build
#     shape)
#   File "/home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/keras/layers/merge.py", line 61, in _compute_elemwise_op_output_shape
#     str(shape1) + ' ' + str(shape2))
# ValueError: Operands could not be broadcast together with shapes (20, 20, 256) (20, 20, 512)

# %%
#CONVERT RPN
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_keras_model_file("model_rpn.h5")
tflite_model = converter.convert()
open("model_rpn.tflite", "wb").write(tflite_model)
# Out:
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/lite/python/lite.py:591: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.convert_variables_to_constants
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/graph_util_impl.py:245: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.compat.v1.graph_util.extract_sub_graph
# INFO:tensorflow:Froze 122 variables.
# INFO:tensorflow:Converted 122 variables to const ops.
# 7058712

# %%
import tensorflow as tf
from keras_frcnn.RoiPoolingConv import RoiPoolingConv

custom_objects = {
    "RoiPoolingConv" : RoiPoolingConv,
}
converter = tf.lite.TFLiteConverter.from_keras_model_file("model_cls.h5",
                                                          custom_objects=custom_objects)
tflite_model = converter.convert()
open("model_cls.tflite", "wb").write(tflite_model)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-ab8fcadf39ad> in <module>
#       5     "RoiPoolingConv" : RoiPoolingConv,
#       6 }
# ----> 7 converter = tf.lite.TFLiteConverter.from_keras_model_file("model_cls.h5",
#       8                                                           custom_objects=custom_objects)
#       9 tflite_model = converter.convert()
#
# AttributeError: type object 'TFLiteConverterV2' has no attribute 'from_keras_model_file'

# %%
#CONVERT CLS
import tensorflow as tf
import keras
from keras_frcnn.RoiPoolingConv import RoiPoolingConv

keras_file = "model_cls.h5"

# Convert the model.
custom_objects = {
    "RoiPoolingConv" : RoiPoolingConv,
}

model = tf.keras.models.load_model(keras_file, custom_objects=custom_objects)

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("model_cls.tflite", "wb").write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-5e4f569a3c90> in <module>
#      11 }
#      12
# ---> 13 model = tf.keras.models.load_model(keras_file, custom_objects=custom_objects)
#      14
#      15 converter = tf.lite.TFLiteConverter.from_keras_model(model)
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     144   if (h5py is not None and (
#     145       isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     166     model_config = json.loads(model_config.decode('utf-8'))
#     167     model = model_config_lib.model_from_config(model_config,
# --> 168                                                custom_objects=custom_objects)
#     169
#     170     # set weights
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/saving/model_config.py in model_from_config(config, custom_objects)
#      53                     '`Sequential.from_config(config)`?')
#      54   from tensorflow.python.keras.layers import deserialize  # pylint: disable=g-import-not-at-top
# ---> 55   return deserialize(config, custom_objects=custom_objects)
#      56
#      57
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/layers/serialization.py in deserialize(config, custom_objects)
#     100       module_objects=globs,
#     101       custom_objects=custom_objects,
# --> 102       printable_module_name='layer')
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     189             custom_objects=dict(
#     190                 list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 191                 list(custom_objects.items())))
#     192       with CustomObjectScope(custom_objects):
#     193         return cls.from_config(cls_config)
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in from_config(cls, config, custom_objects)
#     904     """
#     905     input_tensors, output_tensors, created_layers = reconstruct_from_config(
# --> 906         config, custom_objects)
#     907     model = cls(inputs=input_tensors, outputs=output_tensors,
#     908                 name=config.get('name'))
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in reconstruct_from_config(config, custom_objects, created_layers)
#    1850       if layer in unprocessed_nodes:
#    1851         for node_data in unprocessed_nodes.pop(layer):
# -> 1852           process_node(layer, node_data)
#    1853
#    1854   input_tensors = []
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/tensorflow_core/python/keras/engine/network.py in process_node(layer, node_data)
#    1797       if not isinstance(input_tensors, dict) and len(flat_input_tensors) == 1:
#    1798         input_tensors = flat_input_tensors[0]
# -> 1799       output_tensors = layer(input_tensors, **kwargs)
#    1800
#    1801       # Update node index map.
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     441
#     442             # Handle mask propagation.
# --> 443             previous_mask = _collect_previous_mask(inputs)
#     444             user_kwargs = copy.copy(kwargs)
#     445             if not is_all_none(previous_mask):
#
# ~/miniconda3/envs/tf2/lib/python3.6/site-packages/keras/engine/base_layer.py in _collect_previous_mask(input_tensors)
#    1309             inbound_layer, node_index, tensor_index = x._keras_history
#    1310             node = inbound_layer._inbound_nodes[node_index]
# -> 1311             mask = node.output_masks[tensor_index]
#    1312             masks.append(mask)
#    1313         else:
#
# AttributeError: 'Node' object has no attribute 'output_masks'

# %%
#Sanity Test (does tf_RPN and tflite_RPN have same output?)

import tensorflow as tf
import numpy as np
import time

tf_model = tf.keras.models.load_model("model_rpn.h5")

# Load TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="model_rpn_320.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test model on random input data.
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
# Out:
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
#Inference
interpreter.set_tensor(input_details[0]['index'], input_data)
interpreter.invoke()

#0=cls, 1=reg, 2=base_layers
tflite_results = interpreter.get_tensor(output_details[0]['index'])


# Test the original TensorFlow model on random input data.
#tf_results = tf_model(tf.constant(input_data)) #produces a tf tensor which doesnt show the FUCKING values
tf_results = tf_model.predict(input_data)       #shows values because numpy array yey 
#print(tflite_results.shape)
    
# Compare the result.
# NOTE: only 0 (the cls layer) is tested here, pray that is enough proof
for tf_result, tflite_result in zip(tf_results[0], tflite_results):
    decimal = 5
    error = np.testing.assert_almost_equal(tf_result, tflite_result, decimal=decimal)
    
    #IF no assertion error raised...
    if error==None:
        print("TF and TFLITE models are equal up to {} decimal places".format(decimal))
# Out:
# TF and TFLITE models are equal up to 5 decimal places

# %%
#Sanity Test (get_data)

from keras_frcnn.simple_parser import get_data

voc12_imgs, classes_count, class_mapping = get_data('/home/henri_tomas/projects/voc12/2012_trainval.txt')
voc07_imgs, _, _ = get_data('/home/henri_tomas/projects/voc07/2007_trainval.txt')
#for i in range(len(all_imgs)):
    #print(all_imgs[i])
all_imgs = voc12_imgs + voc07_imgs

#Should print 4087 + 2008 = 6095
print(len(all_imgs))
# Out:
# Parsing annotation files
# Parsing annotation files

# %%
#Sanity Test (get_data)

from keras_frcnn.simple_parser import get_data

all_imgs, classes_count, class_mapping = get_data('/home/henri_tomas/projects/faster-rcnn/frcnn-from-scratch-with-keras/2007_2012_trainval.txt')

#Should print 4087 + 2008 = 6095
print(len(all_imgs))
# Out:
# Parsing annotation files
# 6095

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %%
from keras.applications.mobilenet_v2 import MobileNetV2

feature_extractor = MobileNetV2(input_shape=(224,224,3), 
                                include_top=False,
                                weights='imagenet',
                                pooling=None)
feature_extractor.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
import numpy as np
print(np.random.randint(0,2))
# Out:
# 1
